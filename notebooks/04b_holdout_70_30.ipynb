# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))

import pandas as pd
from src.utils import load_config, ensure_dir

cfg = load_config('../config/config.yaml')
OUT = ensure_dir('../outputs')

p1 = OUT/'clean_data.parquet'
if p1.exists():
    df = pd.read_parquet(p1)
else:
    raise FileNotFoundError('未找到 clean_data.parquet ，请先跑 01（以及可选 02/后续步骤）')

df.shape
# Out:
# (5045, 25)

# %%
from src.holdout import run_holdout
res = run_holdout(df=df, cfg=cfg, out_base=OUT)
res.out_dir
res.metrics.head(20)
# Out:
#                       group model  n_train  n_test         r2      rmse  \
# 0          ('corn', 'acid')   ann      714     306  -0.047494  0.056206
# 1          ('corn', 'acid')    rf      714     306   0.307657  0.041666
# 2          ('corn', 'acid')   svm      714     306   0.503956  0.036790
# 3          ('corn', 'acid')   xgb      714     306   0.464581  0.036611
# 4      ('corn', 'alkaline')   ann      278     120   0.035377  0.095900
# 5      ('corn', 'alkaline')    rf      278     120   0.466951  0.066192
# 6      ('corn', 'alkaline')   svm      278     120   0.622246  0.059367
# 7      ('corn', 'alkaline')   xgb      278     120   0.770120  0.043557
# 8       ('corn', 'neutral')   ann      268     115 -56.120670  0.239579
# 9       ('corn', 'neutral')    rf      268     115   0.292209  0.027471
# 10      ('corn', 'neutral')   svm      268     115   0.400266  0.028027
# 11      ('corn', 'neutral')   xgb      268     115   0.569955  0.021421
# 12  ('corn', 'strong_acid')   ann      965     414  -0.052508  0.044111
# 13  ('corn', 'strong_acid')    rf      965     414   0.331592  0.034535
# 14  ('corn', 'strong_acid')   svm      965     414   0.387271  0.035025
# 15  ('corn', 'strong_acid')   xgb      965     414   0.633951  0.025577
# 16       ('potato', 'acid')   ann      350     151  -0.017049  0.084721
# 17       ('potato', 'acid')    rf      350     151   0.321966  0.064578
# 18       ('potato', 'acid')   svm      350     151   0.539555  0.054408
# 19       ('potato', 'acid')   xgb      350     151   0.539491  0.053221
#
#          mae  test_size  random_state  split_by_group  mix_train_into_test  \
# 0   0.033603        0.3            42            True                 True
# 1   0.017346        0.3            42            True                 True
# 2   0.023165        0.3            42            True                 True
# 3   0.010586        0.3            42            True                 True
# 4   0.060696        0.3            42            True                 True
# 5   0.037468        0.3            42            True                 True
# 6   0.034128        0.3            42            True                 True
# 7   0.015938        0.3            42            True                 True
# 8   0.197288        0.3            42            True                 True
# 9   0.012128        0.3            42            True                 True
# 10  0.017505        0.3            42            True                 True
# 11  0.005674        0.3            42            True                 True
# 12  0.028165        0.3            42            True                 True
# 13  0.017256        0.3            42            True                 True
# 14  0.022669        0.3            42            True                 True
# 15  0.009923        0.3            42            True                 True
# 16  0.049403        0.3            42            True                 True
# 17  0.028366        0.3            42            True                 True
# 18  0.026673        0.3            42            True                 True
# 19  0.014033        0.3            42            True                 True
#
#     mix_fraction
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0
# 5            1.0
# 6            1.0
# 7            1.0
# 8            1.0
# 9            1.0
# 10           1.0
# 11           1.0
# 12           1.0
# 13           1.0
# 14           1.0
# 15           1.0
# 16           1.0
# 17           1.0
# 18           1.0
# 19           1.0

# %%
pngs = sorted(res.fig_dir.glob("*.png"))
len(pngs), pngs[:5]
# Out:
# (64,
#  [WindowsPath('../outputs/holdout_70_30/figures/obs_pred_holdout_corn_acid_ann.png'),
#   WindowsPath('../outputs/holdout_70_30/figures/obs_pred_holdout_corn_acid_rf.png'),
#   WindowsPath('../outputs/holdout_70_30/figures/obs_pred_holdout_corn_acid_svm.png'),
#   WindowsPath('../outputs/holdout_70_30/figures/obs_pred_holdout_corn_acid_xgb.png'),
#   WindowsPath('../outputs/holdout_70_30/figures/obs_pred_holdout_corn_alkaline_ann.png')])

# %%
import sys
from pathlib import Path
sys.path.append(str(Path("..").resolve()))
