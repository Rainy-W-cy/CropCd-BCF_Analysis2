# %% [markdown]
# # 01 数据读取与字段核对（任务书：数据整理）

# %%
import sys
from pathlib import Path
# 让 notebook 能 import src
sys.path.append(str(Path('..').resolve()))

import pandas as pd
import numpy as np

from src.utils import load_config, ensure_dir, set_seed

cfg = load_config('../config/config.yaml')
set_seed(cfg['project']['seed'])
OUT = ensure_dir('../outputs')

# %%
from src.data_io import read_excel_as_long, add_ph_bins, basic_clean
from src.audit import data_audit, enforce_required_columns

raw = read_excel_as_long(cfg)
raw = basic_clean(raw)
raw = add_ph_bins(raw, cfg)

enforce_required_columns(raw, cfg)
audit = data_audit(raw)

audit.to_excel(OUT/'data_audit.xlsx', index=False)
raw.to_parquet(OUT/'clean_data.parquet', index=False)
audit.head(20)
# Out:
#                    column    dtype  missing_n  missing_rate  n_unique
# 24                   crop      str          0           0.0         2
# 25      ph_bin_from_sheet      str          0           0.0         4
# 26                 ph_bin   string          0           0.0         4
# 18          Land use type    int64          0           0.0         5
# 23           source_sheet      str          0           0.0         8
# 21  Vegetation cover type    int64          0           0.0        10
# 19              soil type    int64          0           0.0        20
# 7                 geology    int64          0           0.0        33
# 4                 crop Cd  float64          0           0.0       267
# 11                      K  float64          0           0.0       357
# 3                      pH  float64          0           0.0       459
# 13                    CEC  float64          0           0.0       676
# 12                    SOM  float64          0           0.0       679
# 17           sand content  float64          0           0.0       864
# 6                altitude    int64          0           0.0       896
# 15       Particle content  float64          0           0.0      1107
# 16           clay content  float64          0           0.0      1292
# 2                 soil Cd  float64          0           0.0      1463
# 10                      P    int64          0           0.0      1590
# 8                      Mn  float64          0           0.0      1813
