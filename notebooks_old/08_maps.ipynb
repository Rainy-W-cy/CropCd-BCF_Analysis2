# %% [markdown]
# # 08 经纬度空间地图输出（点位地图）
#
# - 不依赖 GIS 库：用经纬度散点 + 变量着色
# - 支持按 `crop × ph_bin` 分区输出
#
# 输出：`outputs/maps/` 下 `map_*.png`

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))

import pandas as pd
from src.utils import load_config, ensure_dir

cfg = load_config('../config/config.yaml')
OUT = ensure_dir('../outputs')

# %%
p1 = OUT/'bcf_final.parquet'
p2 = OUT/'clean_data.parquet'
df = pd.read_parquet(p1) if p1.exists() else pd.read_parquet(p2)
df.shape
# Out:
# (5045, 29)

# %%
from src.maps import make_maps
outs = make_maps(df, cfg, OUT)
len(outs), outs[:3]
# Out:
# (48,
#  [WindowsPath('../outputs/maps/map_corn_acid_bcf_calc.png'),
#   WindowsPath('../outputs/maps/map_corn_acid_pH.png'),
#   WindowsPath('../outputs/maps/map_corn_acid_soil Cd.png')])

# %% [markdown]
# 如果你的经纬度列名不同，请在 `config.yaml` 增加：
#
# ```yaml
# map_output:
#   lon_col: "你的经度列名"
#   lat_col: "你的纬度列名"
#   out_subdir: "maps"
#   by_group: true
# ```
